# %% [markdown]
# # THEORY QUESTIONS
# 1. What is Object-Oriented Programming (OOP)?
# - Object-Oriented Programming (OOP)is a programming approach that uses sets of objects instead of logic-based methods. It stores data and related operations in the form of abstract data classes. These data classes are then used multiple times to generate new objects with the same functions.
# It is used to structure a software program into simple, reusable pieces of code blueprints.
#
# 2. What is a class in OOP?
# - Classes are simply blueprints for creating objects.It is a model or blueprint of an object that specifies all the properties of the objects. Classes have the data and its associated function wrap in it.
# The class defines the state and behaviours of an object. Before creating an object you know what the properties an object will contains based on the class.
# The beauty of classes is that they allow you to create objects that behave in a consistent and predictable way.
# A class has its own attributes, objects, and methods.
# > Attributes: What the class looks like
# > Methods: What the class does
# > Objects: What the class is.
#
# 3. What is an object in OOP?
# - In Object-Oriented Programming (OOP) in Python, an object is a fundamental building block that represents a real-world entity or concept.
#
# 4. What is the difference between abstraction and encapsulation?
# - Abstraction and encapsulation are two fundamental concepts in OOP that help in designing and structuring classes and objects effectively.
#
# > Abstraction - It emphasizes the creation of clear and simplified interfaces that hide implementation details. It allows you to represent essential features of an object while hiding unnecessary details. It focuses on defining a common structure that highlights what an object does instead of how it does it.
#
# > Encapsulation- It emphasizes data hiding and controlled access to attributes and methods within a class. It is about packaging related data and behavior together and limiting external access to it. It restricts direct access to some components of an object and provides controlled access through methods.
#
# 5. What are dunder methods in Python?
# - Dunder Methods, also known as magic methods. they use as special syntax to perform class-specific operations in Python.“dunder” is the short term used for “double underscores”.
# Dunder methods are special methods in Python that have names beginning and ending with double underscores (__). They’re automatically work by certain Python operations and built-in functions.
# >For example:
#
# - "_ _init_ _" is called when an object is created
#
# - " _ _str_ _" defines how it is printed
#
# - "_ _add_ _" lets you use the '+' operator
#
# 6.  Explain the concept of inheritance in OOP?
# - Inheritance is one of the core features of object-oriented programming. It is a programming procedure that allows you to reuse code by referencing the behaviors and data of an object.
#
# >BENEFITS:
#
#   - Code reusablity
#
#   - Modularity
#
#   - Extensiblity
#
# >OOPS support six different types of inheritance:-
# - Single Inheritance
# - Multi-level Inheritance
# - Multiple Inheritance
# - Multipath Inheritance
# - Hierarchical Inheritance
# - Hybrid Inheritance
#
# 7.  What is polymorphism in OOP?
# - Polymorphism in Object-Oriented Programming (OOP) refers to the ability of different objects to respond to the same method or operation in their own unique way.
#
# - In Python polymorphism allows methods in different classes to share the same name but behave differently based on the object calling them. This makes code more flexible and reusable.
#
# - Polymorphism is a powerful tool in Python, providing flexibility and extensibility to your code.
#
# 8.  How is encapsulation achieved in Python?
# - Encapsulation in Python is achieved primarily through:
#
# >1. Using Access Modifiers - Using naming conventions to indicate protected or private members like single underscore (" _ _") or double underscore ("__ _")
#
# example:
#
# class MyClass:
#
#     def __init__(self):
#         self._name = "John"  # protected
#
#
# >2. Providing controlled access via getter and setter methods.
#
# example:
#
# class MyClass:
#
#    def __init__(self):
#         self.__name = "harry"
#
#     def get_name(self):
#         return self.__name
#
#     def set_name(self, name):
#         self.__name = name
#
#
# >3. Using @property decorators for cleaner code.
# example:
#
#  class MyClass:
#
#     def __init__(self):
#         self.__name = "harry"
#
#     @property
#     def name(self):
#         return self.__name
#
#     @name.setter
#     def name(self, value):
#         self.__name = value
#
# 9. What is a constructor in Python?
# - In Object-Oriented Programming (OOP) in Python, a constructor is a special method used to initialize an object when it is created. It allows you to set up the initial state of an object by assigning values to its attributes or performing any setup tasks.
#
#  The constructor method is named "_ _init_ _". It is automatically called when an object of a class is instantiated.In Python, a constructor is a special method used to initialize objects of a class.
#
# 10. What are class and static methods in Python?
# - Characteristics of Python Class Methods:
#   - Bound to the class, not the instance.
#   - Can access and modify class state.
#   - Defined with the @classmethod decorator.
#
# - Characteristics of Python Static Methods:
#   - Not bound to the class or instance.
#   - Cannot access or modify class or instance state.
#   - Defined with the @staticmethod decorator.
#
# --- The difference between the Class method and the static method is:
#
#   - A class method takes cls as the first parameter while a static method needs no specific parameters.
#   - A class method can access or modify the class state while a static method can't access or modify it.
#   - In general, static methods know nothing about the class state. They are utility-type methods that take some parameters and work upon those parameters. On the other hand class methods must have class as a parameter.
#
# 11. What is method overloading in Python?
# - In Object-Oriented Programming , method overloading refers to defining multiple methods with the same name but different numbers or types of parameters. It's used to provide multiple behaviors under one method name based on arguments.
#
# 12. What is method overriding in OOP?
# - Method overriding is a core concept in OOP that allows a child class (subclass) to provide a specific implementation of a method that is already defined in its parent class (superclass).
#    - To customize or extend the behavior of a method from a base class.
#
#    -  To support polymorphism: treating different objects in the same way but getting different behavior.
#
# 13. What is a property decorator in Python?
# - The property decorator in Python is used to define a method as a property, so you can access it like an attribute—without calling it like a function.
#
# >To encapsulate instance variables.
#
# >To allow getter behavior with a method that looks like an attribute.
#
# >To add controlled access to a class attribute.
#
# 14. Why is polymorphism important in OOP?
# - Key Reasons Polymorphism Is Important:
#   - It  Simplifies the code - We can write generalized code that works on objects of different types.
#   - It Supports Code Reuse - We don’t need to duplicate code for each subclass.
#   - It Enables Flexibility and Extensibility - We can add new classes (new "forms") without changing existing code.
#
# 15. What is an abstract class in Python?
# - In Python, an abstract class is a class that cannot be instantiated on its own and is designed to be a blueprint for other classes. Abstract classes allow us to define methods that must be implemented by subclasses, ensuring a consistent interface while still allowing the subclasses to provide specific implementations.
#
# 16. What are the advantages of OOP?
# - Advantages of Object-Oriented Programming (OOP) include:-
#
#    a) Simplifying debugging
#
#    b) Harnessing code reusability for enhanced efficiency
#
#    c) Amplifying productivity through OOP practices
#
#    d) Streamlining data management to reduce redundancy
#
#    e) Embracing code flexibility for adaptable solutions
#
#    f) Problem-solving capabilities
#
#    g) Enhanced security measures
#
#    h) Improved code structuring and organisation
#
# 17. What is the difference between a class variable and an instance variable?
# - Class Variables
#
#     Class variables, also known as static variables. They are variables that are shared among all instances of a class. They are typically used to store data that is common to all instances of a class.
#
#     They are initialized only once, typically when the class is first loaded into memory.
#
#     They retain their value until the program terminates or the class is explicitly unloaded.
#
#  - Instance Variables
#
#     Instance variables, also known as non-static variables, are variables that are unique to each instance of a class.
#     They are used to store data that is specific to each instance of a class.
#     These variables are initialized when an instance of the class is created. Each instance has its own set of initial values for the instance variables. These values can be assigned during object creation or set through methods or constructors.
#
# 18. What is multiple inheritance in Python?
# - When a class is derived from more than one base class, this types of inheritance is called multiple inheritance in Python.
#
#     It allows a child class to inherit all the properties and methods from multiple parent classes.
#
#     In the multiple inheritance, there are two or more parent classes and one child class.
#
# 19. Explain the purpose of "_ _str_ __" and "_repr_ _" methods in Python?
# - Both are special methods in Python used to define how an object is represented as a string. They help make objects readable.
#  > _ _str_ _() –:
#
#     Called by str() or print()
#
#     Returns a user-friendly string
#
#     used by end users
#
#  > _ _repr_ _() –:
#
#     Called by repr()
#
#     Returns a developer-friendly string thatcould recreate object.
#
#     useful for developers and debugging.
#
# 20. What is the significance of the ‘super()’ function in Python?
# - The super() function in Python is used to call methods from a parent (super) class.
#
#     It plays a key role in inheritance and method overriding, allowing you to reuse and extend functionality from a base class without hardcoding class names.
# 21. What is the significance of the __del__ method in Python?
# - The __del__() method is a special method in Python known as a destructor.
#
#     It's called when an object is about to be destroyed, typically when there are no more references to it.
#
#     If an object implements the _ _del_ _ method, Python calls the _ _del_ _ method right before the garbage collector destroys the object.
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
# - The difference between the Class method and the static method are:-
#
#    - A class method takes cls as the first parameter while a static method needs no specific parameters.
#
#    - A class method can access or modify the class state while a static method can't access or modify it.
#
#    - Static methods know nothing about the class state. They are utility-type methods that take some parameters and work upon those parameters. On the other hand class methods must have class as a parameter.
#
#    - Classmethod decorator in python to create a class method and we use Staticmethod decorator to create a static method in python.
#
# 24. What is method chaining in Python OOP?
# - Method chaining is a technique in Object-Oriented Programming (OOP) where multiple methods are called in a single line using dot (.) notation.
#     Each method returns the object itself, allowing calls to be "chained" together.
#
#     It Makes code cleaner, shorter, and more readable
#
# - Method chaining has two useful benefits:-
#
#    - It can reduce the length of the overall code as countless variables do not have to be created.
#
#    - It can increase the readability of the code since methods are invoked sequentially.
#
# 25. What is the purpose of the __call__ method in Python?
# - The __call__ method enables Python programmers to write classes where the instances behave like functions and can be called like a function.
#
#     It Allows an object to be "called" like a function
#
#     It Makes classes more flexible and enables function-like behavior
#
#
#
#
#      -------------------------------------------------------------------

# %% [markdown]
# # PRACTICAL QUESTIONS :-

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message.
#Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("The animal makes sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

generic_animal = Animal()
generic_animal.speak()
dog = Dog()
dog.speak()
# Out:
# The animal makes sound.
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both

from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class for Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class for Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute

class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

class Car(Vehicle):
    def __init__(self, car_type):
        super().__init__(car_type)

class ElectricCar(Car):
    def __init__(self, car_type, battery_capacity):
        super().__init__(car_type)
        self.battery_capacity = battery_capacity

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# Base class
class Bird:
    def fly(self):
        print("Bird is flying...")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, they swim instead.")

# polymorphism
def bird_flight(bird):
    bird.fly()


if __name__ == "__main__":
    sparrow = Sparrow()
    penguin = Penguin()

    bird_flight(sparrow)
    bird_flight(penguin)
# Out:
# Sparrow flies high in the sky.
# Penguins can't fly, they swim instead.

# %%
#5. . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance

class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        else:
            print("Insufficient funds or invalid amount.")

    def check_balance(self):
        print(f"Current Balance: ${self.__balance}")

# %%
#6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# Base class
class Instrument:
    def play(self):
        print("Playing an instrument...")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# Function forruntime polymorphism
def start_playing(instrument):
    instrument.play()

# %%
# 7. . Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    # Class method: uses cls parameter
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method: does not use self or cls
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example:
if __name__ == "__main__":
    # Call class method
    sum_result = MathOperations.add_numbers(15, 5)
    print(f"Sum: {sum_result}")

    # Call static method
    diff_result = MathOperations.subtract_numbers(15, 5)
    print(f"Difference: {diff_result}")
# Out:
# Sum: 20
# Difference: 10

# %%
# 8. Implement a class Person with a class method to count the total number of persons created

class Person:
    # Class variable to keep track of person count
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Example usage
if __name__ == "__main__":
    p1 = Person("esha")
    p2 = Person("yashi")
    p3 = Person("harry")

    print(f"Total Persons Created: {Person.total_persons()}")
# Out:
# Total Persons Created: 3

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator"
